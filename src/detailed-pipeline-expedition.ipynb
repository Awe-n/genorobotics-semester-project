# %% [markdown]
# # Jupyter Notebook GenoRobotics Full Pipeline

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from lib.consensus.consensus import run_consensus
from lib.identification.identification import run_identification
from lib.general_helpers.process_fastq import concatenate_fastq, extract_gz

# %% [markdown]
# ## Define Your File and Folder Paths
#
# - Modify the "input_src" variable to point to the directory containing the input files.
#
# - Modify the "output_src" variable to point to the directory where you want the output files to be saved.

# %%
expedition_folder = "matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st"
consensus_method = "80_20_best_sequence"
wsl = True

# %%
input_base = 'assets/input'

# %% [markdown]
# ## Run Identification of Consensus Sequence

# %%
for root, dirs, files in os.walk(input_base):
        if root.endswith('fastq_pass'):
            i = 0
            for barcode_folder in dirs:
                print("Processing barcode folder: ", barcode_folder, " still in progress : ", i/len(dirs)*100, "%")
                barcode_path = os.path.join(root, barcode_folder)
                output_fastq = os.path.join(barcode_path, f"{barcode_folder}.fastq")
                intermediate_files = []

                # Extract .gz files and store paths for later deletion
                if not os.path.isfile(output_fastq):
                    for file in os.listdir(barcode_path):
                        if file.endswith('.gz'):
                            src_file = os.path.join(barcode_path, file)
                            dst_file = os.path.join(barcode_path, file[:-3])
                            extract_gz(src_file, dst_file)
                            intermediate_files.append(dst_file)

                    concatenate_fastq(barcode_path, output_fastq)

                    run_consensus(barcode_folder, output_fastq, consensus_method, barcode_path, wsl=wsl)

                if os.path.getsize(os.path.join(barcode_path, f"{barcode_folder}_final_consensus.fasta")) != 0 :
                    print("Running identification for barcode folder: ", barcode_folder)
                    run_identification(barcode_folder, expedition_name=expedition_folder, input_path=barcode_path)


                # Delete intermediary files
                for file in intermediate_files:
                    os.remove(file)

                i += 1
                print("\n")
# Out:
# Processing barcode folder:  barcode02  still in progress :  0.0 %
#
#
# Processing barcode folder:  barcode07  still in progress :  2.272727272727273 %
#
#
# Processing barcode folder:  barcode10  still in progress :  4.545454545454546 %
#
#
# Processing barcode folder:  barcode11  still in progress :  6.8181818181818175 %
#
#
# Processing barcode folder:  barcode18  still in progress :  9.090909090909092 %
#
#
# Processing barcode folder:  barcode19  still in progress :  11.363636363636363 %
#
#
# Processing barcode folder:  barcode20  still in progress :  13.636363636363635 %
#
#
# Processing barcode folder:  barcode33  still in progress :  15.909090909090908 %
#
#
# Processing barcode folder:  barcode45  still in progress :  18.181818181818183 %
#
#
# Processing barcode folder:  barcode46  still in progress :  20.454545454545457 %
#
#
# Processing barcode folder:  barcode52  still in progress :  22.727272727272727 %
#
#
# Processing barcode folder:  barcode62  still in progress :  25.0 %
#
#
# Processing barcode folder:  barcode63  still in progress :  27.27272727272727 %
#
#
# Processing barcode folder:  barcode65  still in progress :  29.545454545454547 %
# Running identification for barcode folder:  barcode65
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode65
# Best species for psbA-trnH is Helicteres angustifolia with alignment 91.58878504672897 and evalue 7.35034e-34
# Best species for matK is Canarium pimela with alignment 78.90531342816183 and evalue 4.861914999999999e-51
# Best species for ITS is Acer opalus with alignment 93.62914770572402 and evalue 9.138374999999995e-16
# Best species for rbcL is Balsamocitrus dawei with alignment 80.06464808194241 and evalue 4.58776e-56
#
#
# Processing barcode folder:  barcode66  still in progress :  31.818181818181817 %
# Running identification for barcode folder:  barcode66
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode66
# Best species for psbA-trnH is Acer opalus with alignment 99.51338199513383 and evalue 0.0
# Best species for matK is Acer spicatum with alignment 93.54120267260579 and evalue 0.0
# Best species for ITS is Dioscorea zingiberensis with alignment 94.54545454545455 and evalue 4.4338e-15
# Best species for rbcL is UNVERIFIED: Dendrobium with alignment 100.0 and evalue 5.45127e-15
#
#
# Processing barcode folder:  barcode67  still in progress :  34.090909090909086 %
# Running identification for barcode folder:  barcode67
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode67
# Best species for psbA-trnH is Cassytha filiformis with alignment 90.9090909090909 and evalue 4.7832443100000004e-36
# Best species for matK is Freylinia lanceolata with alignment 84.44976076555024 and evalue 1.51548e-106
# Best species for ITS is Solanum pimpinellifolium with alignment 97.12121212121212 and evalue 0.0
# Best species for rbcL is Alberta magna with alignment 82.47863247863248 and evalue 2.41348e-104
#
#
# Processing barcode folder:  barcode68  still in progress :  36.36363636363637 %
# Running identification for barcode folder:  barcode68
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode68
# Best species for psbA-trnH is Colocasia antiquorum with alignment 93.50282485875707 and evalue 7.127829e-69
# Best species for matK is Freylinia lanceolata with alignment 87.20379146919431 and evalue 2.8889e-128
# Best species for ITS is Solanum pimpinellifolium with alignment 99.59514170040485 and evalue 0.0
# Best species for rbcL is Alberta magna with alignment 83.86411889596603 and evalue 3.60817e-117
#
#
# Processing barcode folder:  barcode69  still in progress :  38.63636363636363 %
# Running identification for barcode folder:  barcode69
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode69
# Best species for psbA-trnH is Cassytha filiformis with alignment 82.74111675126903 and evalue 2.713723523e-38
# Best species for matK is Freylinia lanceolata with alignment 85.5392156862745 and evalue 1.42287e-111
# Best species for ITS is Lycopersicon cheesmanii with alignment 97.77365491651206 and evalue 0.0
# Best species for rbcL is Cinchona pubescens with alignment 85.96491228070175 and evalue 1.35436e-111
#
#
# Processing barcode folder:  barcode70  still in progress :  40.909090909090914 %
#
#
# Processing barcode folder:  barcode72  still in progress :  43.18181818181818 %
#
#
# Processing barcode folder:  barcode73  still in progress :  45.45454545454545 %
# Running identification for barcode folder:  barcode73
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode73
# Best species for psbA-trnH is Ixora coccinea with alignment 84.21052631578947 and evalue 9.62248e-26
# Best species for matK is Tittmannia laevis with alignment 82.99319727891157 and evalue 5.6991e-66
# Best species for ITS is Solanum pimpinellifolium with alignment 91.00449775112443 and evalue 0.0
# Best species for rbcL is Ixora parviflora with alignment 83.27645051194538 and evalue 4.19305e-67
#
#
# Processing barcode folder:  barcode74  still in progress :  47.72727272727273 %
# Running identification for barcode folder:  barcode74
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode74
# Best species for psbA-trnH is Sarcandra glabra with alignment 92.16867469879519 and evalue 2.78128e-61
# Best species for matK is Cyclocarya paliurus with alignment 86.18421052631578 and evalue 3.65694e-83
# Best species for ITS is Bauhinia jenningsii with alignment 88.36833602584814 and evalue 0.0
# Best species for rbcL is Bauhinia acuminata with alignment 86.33975481611208 and evalue 3.963e-172
#
#
# Processing barcode folder:  barcode75  still in progress :  50.0 %
#
#
# Processing barcode folder:  barcode76  still in progress :  52.27272727272727 %
# Running identification for barcode folder:  barcode76
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode76
# Best species for psbA-trnH is Helicteres angustifolia with alignment 89.01374933897408 and evalue 2.173996668755e-26
# Best species for matK is Asarum europaeum with alignment 100.0 and evalue 0.0
# Best species for ITS is Asarum europaeum with alignment 100.0 and evalue 0.0
# Best species for rbcL is Aristolochia shimadai with alignment 92.74519716885743 and evalue 5.711133475e-65
#
#
# Processing barcode folder:  barcode77  still in progress :  54.54545454545454 %
#
#
# Processing barcode folder:  barcode78  still in progress :  56.81818181818182 %
# Running identification for barcode folder:  barcode78
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode78
# Best species for psbA-trnH is Colocasia antiquorum with alignment 93.0939226519337 and evalue 3.122956e-69
# Best species for matK is Exbucklandia tonkinensis with alignment 87.1875 and evalue 2.87292e-95
# Best species for ITS is Hedera helix with alignment 96.1809585179075 and evalue 3.2922252032532485e-150
# Best species for rbcL is Ferula anatolica with alignment 82.21153846153845 and evalue 4.56085e-93
#
#
# Processing barcode folder:  barcode80  still in progress :  59.09090909090909 %
# Running identification for barcode folder:  barcode80
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode80
# Best species for psbA-trnH is Hedera nepalensis with alignment 97.46151092015754 and evalue 2.30832e-123
# Best species for matK is Aralia racemosa with alignment 92.79158389364304 and evalue 3.197705e-105
# Best species for ITS is Kengyilia geminata with alignment 97.46794871794872 and evalue 3.6101000000000003e-10
# Best species for rbcL is UNVERIFIED: Dendrobium with alignment 97.43589743589743 and evalue 1.93629e-10
#
#
# Processing barcode folder:  barcode81  still in progress :  61.36363636363637 %
# Running identification for barcode folder:  barcode81
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode81
# Best species for psbA-trnH is Erythrophleum fordii with alignment 91.18165784832452 and evalue 0.0
# Best species for matK is Nothoscordum inutile with alignment 98.23943661971832 and evalue 0.0
# Best species for ITS is Allium ovalifolium with alignment 99.10873440285205 and evalue 0.0
# Best species for rbcL is Allium ampeloprasum with alignment 99.11971830985915 and evalue 0.0
#
#
# Processing barcode folder:  barcode82  still in progress :  63.63636363636363 %
# Running identification for barcode folder:  barcode82
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode82
# Best species for psbA-trnH is Colocasia antiquorum with alignment 88.92882530181612 and evalue 2.978925e-50
# Best species for matK is Astragalus macrocephalus with alignment 94.26658551430312 and evalue 4.0471321e-61
# Best species for ITS is Allium ursinum with alignment 99.35321524768521 and evalue 0.0
# Best species for rbcL is Caragana hololeuca with alignment 94.2665855143031 and evalue 1.067582e-61
#
#
# Processing barcode folder:  barcode83  still in progress :  65.9090909090909 %
#
#
# Processing barcode folder:  barcode84  still in progress :  68.18181818181817 %
# Running identification for barcode folder:  barcode84
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode84
# Best species for psbA-trnH is Allium senescens with alignment 96.65551839464884 and evalue 0.0
# Best species for matK is Maianthemum racemosum with alignment 96.79012345679013 and evalue 0.0
# Best species for ITS is Allium sikkimense with alignment 97.45762711864407 and evalue 0.0
# Best species for rbcL is Sabal etonia with alignment 93.36609336609337 and evalue 3.09978e-168
#
#
# Processing barcode folder:  barcode85  still in progress :  70.45454545454545 %
# Running identification for barcode folder:  barcode85
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode85
# Best species for psbA-trnH is Erythrophleum fordii with alignment 94.15807560137456 and evalue 0.0
# Best species for matK is Crataegus mollis with alignment 99.29453262786596 and evalue 0.0
# Best species for ITS is Pyracantha crenulata with alignment 99.48453608247422 and evalue 0.0
# Best species for rbcL is Stranvaesia davidiana with alignment 99.82817869415808 and evalue 0.0
#
#
# Processing barcode folder:  barcode86  still in progress :  72.72727272727273 %
# Running identification for barcode folder:  barcode86
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode86
# Best species for psbA-trnH is Ixora coccinea with alignment 83.33333333333334 and evalue 2.70812e-26
# Best species for matK is Rosa hybrid with alignment 85.87537288709746 and evalue 3.46429081935e-122
# Best species for ITS is Photinia niitakayamensis with alignment 95.4499401307912 and evalue 0.0
# Best species for rbcL is Celtis koraiensis with alignment 83.18385650224215 and evalue 4.02607e-107
#
#
# Processing barcode folder:  barcode87  still in progress :  75.0 %
# Running identification for barcode folder:  barcode87
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode87
# Best species for psbA-trnH is UNVERIFIED: Ocotea with alignment 92.24489795918367 and evalue 0.0
# Best species for matK is Asarum canadense with alignment 95.80712788259959 and evalue 0.0
# Best species for ITS is Asarum caudigerum with alignment 95.63318777292578 and evalue 0.0
# Best species for rbcL is Asarum arifolium with alignment 95.9266802443992 and evalue 0.0
#
#
# Processing barcode folder:  barcode88  still in progress :  77.27272727272727 %
# Running identification for barcode folder:  barcode88
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode88
# Best species for psbA-trnH is None with alignment 0 and evalue inf
# Best species for matK is None with alignment 0 and evalue inf
# Best species for ITS is None with alignment 0 and evalue inf
# Best species for rbcL is None with alignment 0 and evalue inf
#
#
# Processing barcode folder:  barcode89  still in progress :  79.54545454545455 %
# Running identification for barcode folder:  barcode89
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode89
# Best species for psbA-trnH is Cassytha filiformis with alignment 91.73553719008265 and evalue 9.03177994812e-37
# Best species for matK is Chionophila tweedyi with alignment 93.11749288179058 and evalue 6.41875e-79
# Best species for ITS is Solanum pimpinellifolium with alignment 90.96404361921603 and evalue 6.05935e-118
# Best species for rbcL is Sympegma regelii with alignment 99.11853889006417 and evalue 1.6934274865e-79
#
#
# Processing barcode folder:  barcode90  still in progress :  81.81818181818183 %
# Running identification for barcode folder:  barcode90
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode90
# Best species for psbA-trnH is Annona muricata with alignment 99.56140350877193 and evalue 1.25127e-115
# Best species for matK is None with alignment 0 and evalue inf
# Best species for ITS is None with alignment 0 and evalue inf
# Best species for rbcL is None with alignment 0 and evalue inf
#
#
# Processing barcode folder:  barcode91  still in progress :  84.0909090909091 %
# Running identification for barcode folder:  barcode91
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode91
# Best species for psbA-trnH is Zingiber kawagoi with alignment 98.11320754716981 and evalue 5.57233e-46
# Best species for matK is Bambusa ventricosa with alignment 95.14563106796116 and evalue 2.11795e-38
# Best species for ITS is Rohdea wattii with alignment 95.14563106796116 and evalue 1.63651e-38
# Best species for rbcL is Kengyilia melanthera with alignment 92.23300970873787 and evalue 5.63626e-34
#
#
# Processing barcode folder:  barcode92  still in progress :  86.36363636363636 %
#
#
# Processing barcode folder:  barcode93  still in progress :  88.63636363636364 %
# Running identification for barcode folder:  barcode93
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode93
# Best species for psbA-trnH is Erythrophleum fordii with alignment 96.39769452449568 and evalue 0.0
# Best species for matK is Spachea correae with alignment 95.57522123893806 and evalue 0.0
# Best species for ITS is Bauhinia purpurea with alignment 98.84232295306799 and evalue 0.0
# Best species for rbcL is Bauhinia longifolia with alignment 99.41520467836257 and evalue 0.0
#
#
# Processing barcode folder:  barcode94  still in progress :  90.9090909090909 %
# Running identification for barcode folder:  barcode94
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode94
# Best species for psbA-trnH is Erythrophleum fordii with alignment 93.7007874015748 and evalue 0.0
# Best species for matK is Morus alba with alignment 95.11811023622047 and evalue 0.0
# Best species for ITS is Sterculia urens with alignment 99.33665008291874 and evalue 0.0
# Best species for rbcL is Ficus microcarpa with alignment 98.4251968503937 and evalue 0.0
#
#
# Processing barcode folder:  barcode95  still in progress :  93.18181818181817 %
# Running identification for barcode folder:  barcode95
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode95
# Best species for psbA-trnH is Sarcandra glabra with alignment 90.5580215599239 and evalue 1.1925426999999998e-59
# Best species for matK is Ficus carica with alignment 93.7237163076377 and evalue 0.0
# Best species for ITS is Ficus religiosa with alignment 98.99839249934128 and evalue 0.0
# Best species for rbcL is Celtis koraiensis with alignment 80.47727764664654 and evalue 5.273527399999999e-81
#
#
# Processing barcode folder:  barcode96  still in progress :  95.45454545454545 %
# Running identification for barcode folder:  barcode96
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\barcode96
# Best species for psbA-trnH is Ficus carica with alignment 97.99107142857143 and evalue 5.6826e-29
# Best species for matK is Ficus carica with alignment 97.20490995488251 and evalue 2.4871366228714288e-120
# Best species for ITS is Dioscorea zingiberensis with alignment 97.61904761904763 and evalue 9.41943e-12
# Best species for rbcL is Kengyilia melanthera with alignment 97.61904761904763 and evalue 3.22006e-12
#
#
# Processing barcode folder:  unclassified  still in progress :  97.72727272727273 %
# Running identification for barcode folder:  unclassified
# Running consensus pipeline...
#
# You can find identification output at assets\output\matK_rbcL_trnh_ITS_27samples_Jardin_botanique_1st\unclassified
# Best species for psbA-trnH is Allium monanthum with alignment 98.35390946502058 and evalue 0.0
# Best species for matK is Polygonatum pubescens with alignment 96.47577092511013 and evalue 0.0
# Best species for ITS is Allium sikkimense with alignment 98.068669527897 and evalue 0.0
# Best species for rbcL is Sabal etonia with alignment 93.36609336609337 and evalue 1.20835e-167
