# %%
import subprocess
import time
import os

def run_command(command):
    start_time = time.time()
    result = subprocess.run(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Command '{command}' took {elapsed_time:.2f} seconds to run.")
    print(result.stdout)
    print(result.stderr)
    return result, elapsed_time

# Assuming your reads are in 'reads.fastq'
input_fastq_filename = "rbcL_Qiagen_tomato_5000.fastq"
input_fastq_path = f"assets/input/{input_fastq_filename}"
base_name = os.path.splitext(input_fastq_filename)[0]  # Extract base name without extension

output_base_dir = "assets/output"
output_dir = os.path.join(output_base_dir, base_name)

# Make sure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Step 1: Align the reads to each other
paf_alignment_filename = f"reads_{base_name}.paf"
paf_alignment_path = os.path.join(output_dir, paf_alignment_filename)
minimap2_command = f"minimap2 -x ava-ont {input_fastq_path} {input_fastq_path} > {paf_alignment_path}"
_, minimap2_time = run_command(minimap2_command)

# Step 2: Use Racon to generate the consensus sequence from the alignment
consensus_fasta_filename = f"consensus_{base_name}.fasta"
consensus_fasta_path = os.path.join(output_dir, consensus_fasta_filename)
racon_command = f"racon -m 8 -x -6 -g -8 -w 500 {input_fastq_path} {paf_alignment_path} {input_fastq_path} > {consensus_fasta_path}"
_, racon_time = run_command(racon_command)

# Print out the total time for each step
print(f"Minimap2 alignment took {minimap2_time:.2f} seconds.")
print(f"Racon consensus calling took {racon_time:.2f} seconds.")
# Out:
# Command 'minimap2 -x ava-ont assets/input/rbcL_Qiagen_tomato_5000.fastq assets/input/rbcL_Qiagen_tomato_5000.fastq > assets/output/rbcL_Qiagen_tomato_5000/reads_rbcL_Qiagen_tomato_5000.paf' took 37.68 seconds to run.
#
# [M::mm_idx_gen::0.078*1.03] collected minimizers
# [M::mm_idx_gen::0.100*1.45] sorted minimizers
# [M::main::0.100*1.45] loaded/built the index for 5000 target sequence(s)
# [M::mm_mapopt_update::0.103*1.43] mid_occ = 1478
# [M::mm_idx_stat] kmer size: 15; skip: 5; is_hpc: 0; #seq: 5000
# [M::mm_idx_stat::0.106*1.42] distinct minimizers: 171791 (79.28% are singletons); average occurrences: 4.250; average spacing: 3.020; total length: 2204496
# [M::worker_pipeline::37.620*1.64] mapped 5000 sequences
# [M::main] Version: 2.22-r1101
# [M::main] CMD: minimap2 -x ava-ont assets/input/rbcL_Qiagen_tomato_5000.fastq assets/input/rbcL_Qiagen_tomato_5000.fastq
# [M::main] Real time: 37.627 sec; CPU: 61.676 sec; Peak RSS: 0.390 GB
#
# Command 'racon -m 8 -x -6 -g -8 -w 500 assets/input/rbcL_Qiagen_tomato_5000.fastq assets/output/rbcL_Qiagen_tomato_5000/reads_rbcL_Qiagen_tomato_5000.paf assets/input/rbcL_Qiagen_tomato_5000.fastq > assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000.fasta' took 10.05 seconds to run.
#
# [racon::Polisher::initialize] loaded target sequences 0.024559 s
# [racon::Polisher::initialize] loaded sequences 0.026492 s
# [racon::Polisher::initialize] loaded overlaps 4.887553 s
# [racon::Polisher::initialize] aligning overlaps [=>                  ] 0.018573 s
# [racon::Polisher::initialize] aligning overlaps [==>                 ] 0.031733 s
# [racon::Polisher::initialize] aligning overlaps [===>                ] 0.045056 s
# [racon::Polisher::initialize] aligning overlaps [====>               ] 0.057753 s
# [racon::Polisher::initialize] aligning overlaps [=====>              ] 0.070873 s
# [racon::Polisher::initialize] aligning overlaps [======>             ] 0.083782 s
# [racon::Polisher::initialize] aligning overlaps [=======>            ] 0.096599 s
# [racon::Polisher::initialize] aligning overlaps [========>           ] 0.110012 s
# [racon::Polisher::initialize] aligning overlaps [=========>          ] 0.123091 s
# [racon::Polisher::initialize] aligning overlaps [==========>         ] 0.135392 s
# [racon::Polisher::initialize] aligning overlaps [===========>        ] 0.148234 s
# [racon::Polisher::initialize] aligning overlaps [============>       ] 0.160900 s
# [racon::Polisher::initialize] aligning overlaps [=============>      ] 0.173290 s
# [racon::Polisher::initialize] aligning overlaps [==============>     ] 0.186301 s
# [racon::Polisher::initialize] aligning overlaps [===============>    ] 0.199289 s
# [racon::Polisher::initialize] aligning overlaps [================>   ] 0.212149 s
# [racon::Polisher::initialize] aligning overlaps [=================>  ] 0.224721 s
# [racon::Polisher::initialize] aligning overlaps [==================> ] 0.237576 s
# [racon::Polisher::initialize] aligning overlaps [===================>] 0.251034 s
# [racon::Polisher::initialize] aligning overlaps [====================] 0.264179 s
# [racon::Polisher::initialize] transformed data into windows 0.045970 s
# [racon::Polisher::polish] generating consensus [=>                  ] 0.276529 s
# [racon::Polisher::polish] generating consensus [==>                 ] 0.456030 s
# [racon::Polisher::polish] generating consensus [===>                ] 0.717853 s
# [racon::Polisher::polish] generating consensus [====>               ] 0.906127 s
# [racon::Polisher::polish] generating consensus [=====>              ] 1.077859 s
# [racon::Polisher::polish] generating consensus [======>             ] 1.235566 s
# [racon::Polisher::polish] generating consensus [=======>            ] 1.398419 s
# [racon::Polisher::polish] generating consensus [========>           ] 1.591276 s
# [racon::Polisher::polish] generating consensus [=========>          ] 1.760944 s
# [racon::Polisher::polish] generating consensus [==========>         ] 1.981384 s
# [racon::Polisher::polish] generating consensus [===========>        ] 2.186387 s
# [racon::Polisher::polish] generating consensus [============>       ] 2.489904 s
# [racon::Polisher::polish] generating consensus [=============>      ] 2.834405 s
# [racon::Polisher::polish] generating consensus [==============>     ] 3.168656 s
# [racon::Polisher::polish] generating consensus [===============>    ] 3.480010 s
# [racon::Polisher::polish] generating consensus [================>   ] 3.830398 s
# [racon::Polisher::polish] generating consensus [=================>  ] 4.068928 s
# [racon::Polisher::polish] generating consensus [==================> ] 4.215490 s
# [racon::Polisher::polish] generating consensus [===================>] 4.599540 s
# [racon::Polisher::polish] generating consensus [====================] 4.748420 s
# [racon::Polisher::] total = 10.001898 s
#
# Minimap2 alignment took 37.68 seconds.
# Racon consensus calling took 10.05 seconds.
