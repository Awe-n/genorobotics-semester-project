# %%
import subprocess
import os
import time

def run_command(command):
    print(f"Running command: {command}")
    start_time = time.time()
    result = subprocess.run(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
    elapsed_time = time.time() - start_time
    print(f"Command '{command}' took {elapsed_time:.2f} seconds to run.")
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print("Error:", result.stderr)
    return result, elapsed_time

def main():
    input_fastq_filename = "rbcL_Qiagen_tomato_5000.fastq"
    input_fastq_path = f"assets/input/{input_fastq_filename}"
    base_name = os.path.splitext(input_fastq_filename)[0]

    output_base_dir = "assets/output"
    output_dir = os.path.join(output_base_dir, base_name)
    os.makedirs(output_dir, exist_ok=True)

    total_time_taken = 0

    # Step 0: Quality Control with NanoFilt
    filtered_fastq_path = os.path.join(output_dir, f"{base_name}_filtered.fastq")
    nanofilt_command = f"cat {input_fastq_path} | NanoFilt -q 10 -l 500 > {filtered_fastq_path}"
    print("Running Quality Control with NanoFilt...")
    _, nanofilt_time = run_command(nanofilt_command)
    total_time_taken += nanofilt_time

    # Step 1: Align the reads to each other with minimap2
    paf_alignment_path = os.path.join(output_dir, f"{base_name}_reads.paf")
    minimap2_command = f"minimap2 -x ava-ont {filtered_fastq_path} {filtered_fastq_path} > {paf_alignment_path}"
    print("Running read alignment with minimap2...")
    _, minimap2_time = run_command(minimap2_command)
    total_time_taken += minimap2_time

    # Iterative Correction with Racon
    racon_iterations = 3  # Number of times to run Racon
    consensus_fasta_path = os.path.join(output_dir, f"consensus_{base_name}.fasta")
    for iteration in range(1, racon_iterations + 1):
        racon_command = f"racon -m 8 -x -6 -g -8 -w 500 {filtered_fastq_path} {paf_alignment_path} {consensus_fasta_path} > {output_dir}/consensus_{base_name}_iteration{iteration}.fasta"
        print(f"Running Racon iteration {iteration}...")
        _, racon_time = run_command(racon_command)
        total_time_taken += racon_time
        consensus_fasta_path = f"{output_dir}/consensus_{base_name}_iteration{iteration}.fasta"

    # Print out the total time for each step
    print(f"Quality control with NanoFilt took {nanofilt_time:.2f} seconds.")
    print(f"Minimap2 alignment took {minimap2_time:.2f} seconds.")
    print(f"Total Racon iterations took {total_time_taken - nanofilt_time - minimap2_time:.2f} seconds.")

    # Print out the total time for the pipeline
    print(f"Total time taken for the pipeline: {total_time_taken:.2f} seconds.")

    print(f"Pipeline completed. Find outputs in {output_dir}.")

if __name__ == "__main__":
    main()
# Out:
# Running Quality Control with NanoFilt...
# Running command: cat assets/input/rbcL_Qiagen_tomato_5000.fastq | NanoFilt -q 10 -l 500 > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq
# Command 'cat assets/input/rbcL_Qiagen_tomato_5000.fastq | NanoFilt -q 10 -l 500 > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq' took 0.84 seconds to run.
# Running read alignment with minimap2...
# Running command: minimap2 -x ava-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_reads.paf
# Command 'minimap2 -x ava-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_reads.paf' took 5.01 seconds to run.
# Error: [M::mm_idx_gen::0.030*1.14] collected minimizers
# [M::mm_idx_gen::0.042*1.68] sorted minimizers
# [M::main::0.042*1.68] loaded/built the index for 1390 target sequence(s)
# [M::mm_mapopt_update::0.044*1.65] mid_occ = 861
# [M::mm_idx_stat] kmer size: 15; skip: 5; is_hpc: 0; #seq: 1390
# [M::mm_idx_stat::0.045*1.64] distinct minimizers: 67987 (77.38% are singletons); average occurrences: 4.407; average spacing: 2.974; total length: 891145
# [M::worker_pipeline::4.969*2.70] mapped 1390 sequences
# [M::main] Version: 2.22-r1101
# [M::main] CMD: minimap2 -x ava-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq
# [M::main] Real time: 4.974 sec; CPU: 13.417 sec; Peak RSS: 0.116 GB
#
# Running Racon iteration 1...
# Running command: racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_reads.paf assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000.fasta > assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000_iteration1.fasta
# Command 'racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_reads.paf assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000.fasta > assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000_iteration1.fasta' took 0.05 seconds to run.
# Error: libc++abi: terminating due to uncaught exception of type std::invalid_argument: [bioparser::Parser::Create] error: unable to open file assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000.fasta
# /bin/sh: line 1:   395 Abort trap: 6           racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_reads.paf assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000.fasta > assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000_iteration1.fasta
#
# Running Racon iteration 2...
# Running command: racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_reads.paf assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000_iteration1.fasta > assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000_iteration2.fasta
# Command 'racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_reads.paf assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000_iteration1.fasta > assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000_iteration2.fasta' took 0.03 seconds to run.
# Error: [racon::Polisher::initialize] error: empty target sequences set!
#
# Running Racon iteration 3...
# Running command: racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_reads.paf assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000_iteration2.fasta > assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000_iteration3.fasta
# Command 'racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_filtered.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_reads.paf assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000_iteration2.fasta > assets/output/rbcL_Qiagen_tomato_5000/consensus_rbcL_Qiagen_tomato_5000_iteration3.fasta' took 0.03 seconds to run.
# Error: [racon::Polisher::initialize] error: empty target sequences set!
#
# Quality control with NanoFilt took 0.84 seconds.
# Minimap2 alignment took 5.01 seconds.
# Total Racon iterations took 0.12 seconds.
# Total time taken for the pipeline: 5.97 seconds.
# Pipeline completed. Find outputs in assets/output/rbcL_Qiagen_tomato_5000.
