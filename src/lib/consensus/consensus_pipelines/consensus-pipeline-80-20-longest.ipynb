# %%
import subprocess
import os
import time
import pandas as pd
from Bio import SeqIO

def run_command(command):
    print(f"Running command: {command}")
    start_time = time.time()
    result = subprocess.run(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
    elapsed_time = time.time() - start_time
    print(f"Command '{command}' took {elapsed_time:.2f} seconds to run.")
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print("Error:", result.stderr)
    return result, elapsed_time

def split_fastq(input_path, output_dir, base_name, percentile=20):
    # Read sequences and sort by length
    sequences = list(SeqIO.parse(input_path, "fastq"))
    sequences.sort(key=lambda x: len(x), reverse=True)

    # Split into top percentile and remaining sequences
    split_index = len(sequences) * percentile // 100
    top_sequences = sequences[:split_index]
    remaining_sequences = sequences[split_index:]

    # Write to separate files
    top_sequences_path = os.path.join(output_dir, f"{base_name}_top{percentile}.fastq")
    remaining_sequences_path = os.path.join(output_dir, f"{base_name}_remaining{100-percentile}.fastq")
    SeqIO.write(top_sequences, top_sequences_path, "fastq")
    SeqIO.write(remaining_sequences, remaining_sequences_path, "fastq")

    return top_sequences_path, remaining_sequences_path

def main():
    input_fastq_filename = "rbcL_Qiagen_tomato_5000.fastq"
    input_fastq_path = f"assets/input/{input_fastq_filename}"
    base_name = os.path.splitext(input_fastq_filename)[0]

    output_base_dir = "assets/output"
    output_dir = os.path.join(output_base_dir, base_name)
    os.makedirs(output_dir, exist_ok=True)

    total_time_taken = 0

    # Split the file into top 20% and remaining 80%
    top_sequences_path, remaining_sequences_path = split_fastq(input_fastq_path, output_dir, base_name, percentile=20)

    # Step 1: Align and generate consensus from top 20% sequences
    top_paf_path = os.path.join(output_dir, f"{base_name}_top20_reads.paf")
    top_consensus_path = os.path.join(output_dir, f"{base_name}_top20_consensus.fasta")
    minimap2_command = f"minimap2 -x ava-ont {top_sequences_path} {top_sequences_path} > {top_paf_path}"
    print("Running read alignment with minimap2 on top 20% sequences...")
    _, minimap2_time = run_command(minimap2_command)
    total_time_taken += minimap2_time

    racon_command = f"racon -m 8 -x -6 -g -8 -w 500 {top_sequences_path} {top_paf_path} {top_sequences_path} > {top_consensus_path}"
    print("Generating consensus sequence with racon on top 20% sequences...")
    _, racon_time = run_command(racon_command)
    total_time_taken += racon_time

    # Step 1 bis: If the outputed racon file contains more than one sequence, we take the longest one
    consensus_sequences = list(SeqIO.parse(top_consensus_path, "fasta"))
    if len(consensus_sequences) > 1:
        print(f"Warning: {top_consensus_path} contains more than one sequence. Taking the longest one.")
        consensus_sequences.sort(key=lambda x: len(x), reverse=True)
        SeqIO.write(consensus_sequences[0], top_consensus_path, "fasta")

    # Step 2: Align the remaining 80% sequences to the top 20% consensus
    remaining_paf_path = os.path.join(output_dir, f"{base_name}_remaining80_reads.paf")
    final_consensus_path = os.path.join(output_dir, f"{base_name}_final_consensus.fasta")
    minimap2_command = f"minimap2 -x map-ont {top_consensus_path} {remaining_sequences_path} > {remaining_paf_path}"
    print("Running read alignment with minimap2 on remaining 80% sequences...")
    _, minimap2_time = run_command(minimap2_command)
    total_time_taken += minimap2_time

    # Step 3: Generate the final consensus sequence with racon
    racon_command = f"racon -m 8 -x -6 -g -8 -w 500 {remaining_sequences_path} {remaining_paf_path} {top_consensus_path} > {final_consensus_path}"
    print("Generating final consensus sequence with racon...")
    _, racon_time = run_command(racon_command)
    total_time_taken += racon_time

    # Print out the total time for each step
    print(f"Minimap2 alignment took {minimap2_time:.2f} seconds.")
    print(f"Total Racon iterations took {total_time_taken - minimap2_time:.2f} seconds.")

    # Print out the total time for the pipeline
    print(f"Total time taken for the pipeline: {total_time_taken:.2f} seconds.")

main()
# Out:
# Running read alignment with minimap2 on top 20% sequences...
# Running command: minimap2 -x ava-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_reads.paf
# Command 'minimap2 -x ava-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_reads.paf' took 2.84 seconds to run.
# Error: [M::mm_idx_gen::0.024*1.19] collected minimizers
# [M::mm_idx_gen::0.033*1.70] sorted minimizers
# [M::main::0.033*1.70] loaded/built the index for 1000 target sequence(s)
# [M::mm_mapopt_update::0.035*1.66] mid_occ = 608
# [M::mm_idx_stat] kmer size: 15; skip: 5; is_hpc: 0; #seq: 1000
# [M::mm_idx_stat::0.036*1.65] distinct minimizers: 61942 (78.57% are singletons); average occurrences: 3.831; average spacing: 2.966; total length: 703802
# [M::worker_pipeline::2.788*2.70] mapped 1000 sequences
# [M::main] Version: 2.22-r1101
# [M::main] CMD: minimap2 -x ava-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq
# [M::main] Real time: 2.792 sec; CPU: 7.535 sec; Peak RSS: 0.075 GB
#
# Generating consensus sequence with racon on top 20% sequences...
# Running command: racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_reads.paf assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta
# Command 'racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_reads.paf assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20.fastq > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta' took 2.73 seconds to run.
# Error: [racon::Polisher::initialize] loaded target sequences 0.007550 s
# [racon::Polisher::initialize] loaded sequences 0.007764 s
# [racon::Polisher::initialize] loaded overlaps 0.588287 s
# [racon::Polisher::initialize] aligning overlaps [=>                  ] 0.006706 s
# [racon::Polisher::initialize] aligning overlaps [==>                 ] 0.011071 s
# [racon::Polisher::initialize] aligning overlaps [===>                ] 0.015293 s
# [racon::Polisher::initialize] aligning overlaps [====>               ] 0.019619 s
# [racon::Polisher::initialize] aligning overlaps [=====>              ] 0.024138 s
# [racon::Polisher::initialize] aligning overlaps [======>             ] 0.028490 s
# [racon::Polisher::initialize] aligning overlaps [=======>            ] 0.032927 s
# [racon::Polisher::initialize] aligning overlaps [========>           ] 0.037234 s
# [racon::Polisher::initialize] aligning overlaps [=========>          ] 0.041615 s
# [racon::Polisher::initialize] aligning overlaps [==========>         ] 0.046164 s
# [racon::Polisher::initialize] aligning overlaps [===========>        ] 0.050602 s
# [racon::Polisher::initialize] aligning overlaps [============>       ] 0.054910 s
# [racon::Polisher::initialize] aligning overlaps [=============>      ] 0.059177 s
# [racon::Polisher::initialize] aligning overlaps [==============>     ] 0.063402 s
# [racon::Polisher::initialize] aligning overlaps [===============>    ] 0.067639 s
# [racon::Polisher::initialize] aligning overlaps [================>   ] 0.071620 s
# [racon::Polisher::initialize] aligning overlaps [=================>  ] 0.075676 s
# [racon::Polisher::initialize] aligning overlaps [==================> ] 0.079689 s
# [racon::Polisher::initialize] aligning overlaps [===================>] 0.083625 s
# [racon::Polisher::initialize] aligning overlaps [====================] 0.088394 s
# [racon::Polisher::initialize] transformed data into windows 0.009186 s
# [racon::Polisher::polish] generating consensus [=>                  ] 1.242052 s
# [racon::Polisher::polish] generating consensus [==>                 ] 1.795181 s
# [racon::Polisher::polish] generating consensus [===>                ] 1.920782 s
# [racon::Polisher::polish] generating consensus [====>               ] 1.935199 s
# [racon::Polisher::polish] generating consensus [=====>              ] 1.947082 s
# [racon::Polisher::polish] generating consensus [======>             ] 1.947190 s
# [racon::Polisher::polish] generating consensus [=======>            ] 1.957053 s
# [racon::Polisher::polish] generating consensus [========>           ] 1.961134 s
# [racon::Polisher::polish] generating consensus [=========>          ] 1.961238 s
# [racon::Polisher::polish] generating consensus [==========>         ] 1.961336 s
# [racon::Polisher::polish] generating consensus [===========>        ] 1.969543 s
# [racon::Polisher::polish] generating consensus [============>       ] 1.969784 s
# [racon::Polisher::polish] generating consensus [=============>      ] 1.973871 s
# [racon::Polisher::polish] generating consensus [==============>     ] 1.973974 s
# [racon::Polisher::polish] generating consensus [===============>    ] 1.974073 s
# [racon::Polisher::polish] generating consensus [================>   ] 1.974174 s
# [racon::Polisher::polish] generating consensus [=================>  ] 1.977565 s
# [racon::Polisher::polish] generating consensus [==================> ] 1.981849 s
# [racon::Polisher::polish] generating consensus [===================>] 1.982119 s
# [racon::Polisher::polish] generating consensus [====================] 1.986313 s
# [racon::Polisher::] total = 2.688377 s
#
# Warning: assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta contains more than one sequence. Taking the longest one.
# Running read alignment with minimap2 on remaining 80% sequences...
# Running command: minimap2 -x map-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80.fastq > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80_reads.paf
# Command 'minimap2 -x map-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80.fastq > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80_reads.paf' took 0.05 seconds to run.
# Error: [M::mm_idx_gen::0.001*10.24] collected minimizers
# [M::mm_idx_gen::0.001*7.15] sorted minimizers
# [M::main::0.001*7.10] loaded/built the index for 1 target sequence(s)
# [M::mm_mapopt_update::0.001*6.83] mid_occ = 10
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1
# [M::mm_idx_stat::0.001*6.56] distinct minimizers: 139 (100.00% are singletons); average occurrences: 1.000; average spacing: 5.763; total length: 801
# [M::worker_pipeline::0.024*2.26] mapped 4000 sequences
# [M::main] Version: 2.22-r1101
# [M::main] CMD: minimap2 -x map-ont assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80.fastq
# [M::main] Real time: 0.025 sec; CPU: 0.056 sec; Peak RSS: 0.006 GB
#
# Generating final consensus sequence with racon...
# Running command: racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80_reads.paf assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_final_consensus.fasta
# Command 'racon -m 8 -x -6 -g -8 -w 500 assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80.fastq assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_remaining80_reads.paf assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_top20_consensus.fasta > assets/output/rbcL_Qiagen_tomato_5000/rbcL_Qiagen_tomato_5000_final_consensus.fasta' took 9.05 seconds to run.
# Error: [racon::Polisher::initialize] loaded target sequences 0.000056 s
# [racon::Polisher::initialize] loaded sequences 0.017668 s
# [racon::Polisher::initialize] loaded overlaps 0.005341 s
# [racon::Polisher::initialize] aligning overlaps [=>                  ] 0.026936 s
# [racon::Polisher::initialize] aligning overlaps [==>                 ] 0.035680 s
# [racon::Polisher::initialize] aligning overlaps [===>                ] 0.043455 s
# [racon::Polisher::initialize] aligning overlaps [====>               ] 0.050639 s
# [racon::Polisher::initialize] aligning overlaps [=====>              ] 0.057293 s
# [racon::Polisher::initialize] aligning overlaps [======>             ] 0.063917 s
# [racon::Polisher::initialize] aligning overlaps [=======>            ] 0.070106 s
# [racon::Polisher::initialize] aligning overlaps [========>           ] 0.075790 s
# [racon::Polisher::initialize] aligning overlaps [=========>          ] 0.080922 s
# [racon::Polisher::initialize] aligning overlaps [==========>         ] 0.085690 s
# [racon::Polisher::initialize] aligning overlaps [===========>        ] 0.090250 s
# [racon::Polisher::initialize] aligning overlaps [============>       ] 0.094533 s
# [racon::Polisher::initialize] aligning overlaps [=============>      ] 0.098363 s
# [racon::Polisher::initialize] aligning overlaps [==============>     ] 0.102092 s
# [racon::Polisher::initialize] aligning overlaps [===============>    ] 0.105650 s
# [racon::Polisher::initialize] aligning overlaps [================>   ] 0.109038 s
# [racon::Polisher::initialize] aligning overlaps [=================>  ] 0.112219 s
# [racon::Polisher::initialize] aligning overlaps [==================> ] 0.115406 s
# [racon::Polisher::initialize] aligning overlaps [===================>] 0.118406 s
# [racon::Polisher::initialize] aligning overlaps [====================] 0.121107 s
# [racon::Polisher::initialize] transformed data into windows 0.001659 s
# [racon::Polisher::polish] generated consensus 8.869970 s
# [racon::Polisher::] total = 9.017665 s
#
# Minimap2 alignment took 0.05 seconds.
# Total Racon iterations took 14.62 seconds.
# Total time taken for the pipeline: 14.68 seconds.
