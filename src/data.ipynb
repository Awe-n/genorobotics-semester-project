# %%
from Bio import SeqIO
import matplotlib.pyplot as plt

# %%
fastq_path = 'assets/input/test-combined.fastq'  # Adjust the path if your file is in a different directory

read_lengths = []
read_qualities = []

for record in SeqIO.parse(fastq_path, 'fastq'):
    read_lengths.append(len(record.seq))
    read_qualities.append(record.letter_annotations["phred_quality"])

# %%
plt.figure(figsize=(10, 6))
plt.hist(read_lengths, bins=50, range=(0, 1000), color='blue', alpha=0.7)  # Adjusted bin size and range
plt.title('Distribution of Read Lengths (0 to 1000)')
plt.xlabel('Read Length')
plt.ylabel('Frequency')
plt.show()

# %%
average_qualities = [sum(quals)/len(quals) for quals in read_qualities if len(quals) > 0]

plt.figure(figsize=(10, 6))
plt.hist(average_qualities, bins=30, color='green', alpha=0.7)
plt.title('Distribution of Average Read Qualities')
plt.xlabel('Average Quality Score')
plt.ylabel('Frequency')
plt.show()

# %%
import numpy as np

# Assuming read_lengths and average_qualities are already defined as per previous steps

# Calculate the required statistics
mean_read_length = np.mean(read_lengths)
min_read_length = np.min(read_lengths)
max_read_length = np.max(read_lengths)
num_reads = len(read_lengths)
std_dev_read_length = np.std(read_lengths)
average_read_quality = np.mean(average_qualities)

# Store in a dictionary
filename = 'test.fastq'  # Replace with your actual filename
stats_map = {
    filename: {
        'mean_read_length': mean_read_length,
        'min_read_length': min_read_length,
        'max_read_length': max_read_length,
        'number_of_reads': num_reads,
        'std_dev_read_length': std_dev_read_length,
        'average_read_quality': average_read_quality
    }
}

# To access the stored information, use:
stats_map[filename]
# Out:
# {'mean_read_length': 453.38873333333333,
#  'min_read_length': 125,
#  'max_read_length': 5044,
#  'number_of_reads': 60000,
#  'std_dev_read_length': 199.88657346871057,
#  'average_read_quality': 17.70668201940736}

# %%
from Bio import SeqIO
import numpy as np

def process_fastq_in_blocks_and_store_stats(fastq_path, block_size=1000):
    block_number = 0
    stats_map = {}
    current_block_reads = []
    current_block_qualities = []

    with open(fastq_path, 'r') as fastq_file:
        for record in SeqIO.parse(fastq_file, 'fastq'):
            current_block_reads.append(len(record.seq))
            current_block_qualities.extend(record.letter_annotations["phred_quality"])

            if len(current_block_reads) == block_size:
                # Calculate statistics for the current block
                mean_read_length = np.mean(current_block_reads)
                min_read_length = np.min(current_block_reads)
                max_read_length = np.max(current_block_reads)
                std_dev_read_length = np.std(current_block_reads)
                average_read_quality = np.mean(current_block_qualities)

                # Store in the dictionary
                block_key = f"{fastq_path}_block_{block_number}"
                stats_map[block_key] = {
                    'mean_read_length': mean_read_length,
                    'min_read_length': min_read_length,
                    'max_read_length': max_read_length,
                    'number_of_reads': block_size,
                    'std_dev_read_length': std_dev_read_length,
                    'average_read_quality': average_read_quality
                }

                # Reset for the next block
                current_block_reads = []
                current_block_qualities = []
                block_number += 1

        # Handle the last block if it's not empty and less than block_size
        if current_block_reads:
            mean_read_length = np.mean(current_block_reads)
            min_read_length = np.min(current_block_reads)
            max_read_length = np.max(current_block_reads)
            std_dev_read_length = np.std(current_block_reads)
            average_read_quality = np.mean(current_block_qualities)

            block_key = f"{fastq_path}_block_{block_number}"
            stats_map[block_key] = {
                'mean_read_length': mean_read_length,
                'min_read_length': min_read_length,
                'max_read_length': max_read_length,
                'number_of_reads': len(current_block_reads),
                'std_dev_read_length': std_dev_read_length,
                'average_read_quality': average_read_quality
            }

    return stats_map

# Example usage
fastq_path = 'assets/input/test-combined.fastq'  # Adjust the path if your file is in a different directory
stats_map = process_fastq_in_blocks_and_store_stats(fastq_path)

# %%
stats_map
# Out:
# {'assets/input/test-combined.fastq_block_0': {'mean_read_length': 456.728,
#   'min_read_length': 170,
#   'max_read_length': 934,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 199.21185209720832,
#   'average_read_quality': 18.006730482913245},
#  'assets/input/test-combined.fastq_block_1': {'mean_read_length': 456.146,
#   'min_read_length': 164,
#   'max_read_length': 1078,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 203.23542182405112,
#   'average_read_quality': 17.889776518921572},
#  'assets/input/test-combined.fastq_block_2': {'mean_read_length': 448.373,
#   'min_read_length': 166,
#   'max_read_length': 1024,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 199.8044490770914,
#   'average_read_quality': 17.823310056582354},
#  'assets/input/test-combined.fastq_block_3': {'mean_read_length': 450.373,
#   'min_read_length': 168,
#   'max_read_length': 1296,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 196.21277193648734,
#   'average_read_quality': 17.847066764659516},
#  'assets/input/test-combined.fastq_block_4': {'mean_read_length': 460.836,
#   'min_read_length': 189,
#   'max_read_length': 1208,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 200.71968290130394,
#   'average_read_quality': 17.878577194490013},
#  'assets/input/test-combined.fastq_block_5': {'mean_read_length': 459.77,
#   'min_read_length': 171,
#   'max_read_length': 942,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 197.64953604802616,
#   'average_read_quality': 17.847269286817323},
#  'assets/input/test-combined.fastq_block_6': {'mean_read_length': 456.416,
#   'min_read_length': 141,
#   'max_read_length': 927,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 194.58725277879842,
#   'average_read_quality': 17.78740009114492},
#  'assets/input/test-combined.fastq_block_7': {'mean_read_length': 443.092,
#   'min_read_length': 162,
#   'max_read_length': 948,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 196.97456570836752,
#   'average_read_quality': 17.80488476433788},
#  'assets/input/test-combined.fastq_block_8': {'mean_read_length': 442.328,
#   'min_read_length': 129,
#   'max_read_length': 1115,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 194.49446885708602,
#   'average_read_quality': 17.79258378397931},
#  'assets/input/test-combined.fastq_block_9': {'mean_read_length': 462.377,
#   'min_read_length': 173,
#   'max_read_length': 1447,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 206.69529958612992,
#   'average_read_quality': 17.892728228263948},
#  'assets/input/test-combined.fastq_block_10': {'mean_read_length': 459.901,
#   'min_read_length': 168,
#   'max_read_length': 946,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 194.360801601043,
#   'average_read_quality': 17.895351390842812},
#  'assets/input/test-combined.fastq_block_11': {'mean_read_length': 455.707,
#   'min_read_length': 173,
#   'max_read_length': 1007,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 192.69423746184006,
#   'average_read_quality': 17.778932515849},
#  'assets/input/test-combined.fastq_block_12': {'mean_read_length': 448.543,
#   'min_read_length': 172,
#   'max_read_length': 930,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 199.5769930402801,
#   'average_read_quality': 17.831623723923904},
#  'assets/input/test-combined.fastq_block_13': {'mean_read_length': 454.82,
#   'min_read_length': 158,
#   'max_read_length': 955,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 198.51479441089523,
#   'average_read_quality': 17.95008354953608},
#  'assets/input/test-combined.fastq_block_14': {'mean_read_length': 456.006,
#   'min_read_length': 179,
#   'max_read_length': 998,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 198.2996620370292,
#   'average_read_quality': 17.683980035350412},
#  'assets/input/test-combined.fastq_block_15': {'mean_read_length': 454.109,
#   'min_read_length': 198,
#   'max_read_length': 924,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 198.07112136553374,
#   'average_read_quality': 17.893351596202674},
#  'assets/input/test-combined.fastq_block_16': {'mean_read_length': 457.952,
#   'min_read_length': 161,
#   'max_read_length': 968,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 200.43981564549495,
#   'average_read_quality': 17.822326357347496},
#  'assets/input/test-combined.fastq_block_17': {'mean_read_length': 448.184,
#   'min_read_length': 125,
#   'max_read_length': 1182,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 196.7001630502629,
#   'average_read_quality': 17.9229066633347},
#  'assets/input/test-combined.fastq_block_18': {'mean_read_length': 452.691,
#   'min_read_length': 163,
#   'max_read_length': 1362,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 198.74452827436534,
#   'average_read_quality': 17.854574091378005},
#  'assets/input/test-combined.fastq_block_19': {'mean_read_length': 457.355,
#   'min_read_length': 186,
#   'max_read_length': 930,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 198.7456187567414,
#   'average_read_quality': 17.824915000382635},
#  'assets/input/test-combined.fastq_block_20': {'mean_read_length': 462.389,
#   'min_read_length': 152,
#   'max_read_length': 954,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 208.8532012658652,
#   'average_read_quality': 17.7959964445521},
#  'assets/input/test-combined.fastq_block_21': {'mean_read_length': 444.835,
#   'min_read_length': 153,
#   'max_read_length': 1227,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 193.7105979935016,
#   'average_read_quality': 17.863263906841862},
#  'assets/input/test-combined.fastq_block_22': {'mean_read_length': 452.104,
#   'min_read_length': 150,
#   'max_read_length': 1137,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 195.12528074034896,
#   'average_read_quality': 17.82401394369437},
#  'assets/input/test-combined.fastq_block_23': {'mean_read_length': 457.755,
#   'min_read_length': 147,
#   'max_read_length': 1030,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 198.47137570692655,
#   'average_read_quality': 17.708162663433495},
#  'assets/input/test-combined.fastq_block_24': {'mean_read_length': 454.414,
#   'min_read_length': 177,
#   'max_read_length': 1027,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 201.81977257939818,
#   'average_read_quality': 17.847557513632943},
#  'assets/input/test-combined.fastq_block_25': {'mean_read_length': 456.558,
#   'min_read_length': 153,
#   'max_read_length': 928,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 200.74570141350475,
#   'average_read_quality': 17.80159804449818},
#  'assets/input/test-combined.fastq_block_26': {'mean_read_length': 444.833,
#   'min_read_length': 156,
#   'max_read_length': 939,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 194.70776335575323,
#   'average_read_quality': 17.704435147572234},
#  'assets/input/test-combined.fastq_block_27': {'mean_read_length': 447.666,
#   'min_read_length': 154,
#   'max_read_length': 939,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 195.97423923567098,
#   'average_read_quality': 17.87851210500686},
#  'assets/input/test-combined.fastq_block_28': {'mean_read_length': 457.491,
#   'min_read_length': 161,
#   'max_read_length': 1410,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 198.7456462894219,
#   'average_read_quality': 17.798953422034533},
#  'assets/input/test-combined.fastq_block_29': {'mean_read_length': 461.031,
#   'min_read_length': 179,
#   'max_read_length': 4170,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 231.04290519078918,
#   'average_read_quality': 18.205389659263695},
#  'assets/input/test-combined.fastq_block_30': {'mean_read_length': 453.375,
#   'min_read_length': 163,
#   'max_read_length': 948,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 194.69335472737635,
#   'average_read_quality': 17.860702508960575},
#  'assets/input/test-combined.fastq_block_31': {'mean_read_length': 449.748,
#   'min_read_length': 175,
#   'max_read_length': 937,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 195.48005140167118,
#   'average_read_quality': 17.85931454948104},
#  'assets/input/test-combined.fastq_block_32': {'mean_read_length': 456.661,
#   'min_read_length': 129,
#   'max_read_length': 1064,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 197.94600293766985,
#   'average_read_quality': 17.918353001460602},
#  'assets/input/test-combined.fastq_block_33': {'mean_read_length': 452.322,
#   'min_read_length': 158,
#   'max_read_length': 1052,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 194.12891674348774,
#   'average_read_quality': 17.712682558000715},
#  'assets/input/test-combined.fastq_block_34': {'mean_read_length': 453.814,
#   'min_read_length': 148,
#   'max_read_length': 1102,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 199.14992192817954,
#   'average_read_quality': 17.966157941359235},
#  'assets/input/test-combined.fastq_block_35': {'mean_read_length': 463.615,
#   'min_read_length': 172,
#   'max_read_length': 936,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 200.3058930111643,
#   'average_read_quality': 17.937875176601274},
#  'assets/input/test-combined.fastq_block_36': {'mean_read_length': 447.312,
#   'min_read_length': 168,
#   'max_read_length': 5044,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 240.95547857643746,
#   'average_read_quality': 18.21675474836356},
#  'assets/input/test-combined.fastq_block_37': {'mean_read_length': 454.875,
#   'min_read_length': 168,
#   'max_read_length': 933,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 193.45566772519226,
#   'average_read_quality': 17.74820555097554},
#  'assets/input/test-combined.fastq_block_38': {'mean_read_length': 457.741,
#   'min_read_length': 158,
#   'max_read_length': 1109,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 198.97195761966057,
#   'average_read_quality': 17.88837792550809},
#  'assets/input/test-combined.fastq_block_39': {'mean_read_length': 447.238,
#   'min_read_length': 167,
#   'max_read_length': 931,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 198.69992288876207,
#   'average_read_quality': 17.979453892558325},
#  'assets/input/test-combined.fastq_block_40': {'mean_read_length': 456.76,
#   'min_read_length': 159,
#   'max_read_length': 923,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 195.57131793798393,
#   'average_read_quality': 17.820829319555127},
#  'assets/input/test-combined.fastq_block_41': {'mean_read_length': 447.024,
#   'min_read_length': 178,
#   'max_read_length': 942,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 189.03819567484237,
#   'average_read_quality': 17.93779081212642},
#  'assets/input/test-combined.fastq_block_42': {'mean_read_length': 448.619,
#   'min_read_length': 188,
#   'max_read_length': 939,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 193.72767442727434,
#   'average_read_quality': 17.76879044356124},
#  'assets/input/test-combined.fastq_block_43': {'mean_read_length': 449.549,
#   'min_read_length': 129,
#   'max_read_length': 939,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 198.12924973107832,
#   'average_read_quality': 17.745476021523793},
#  'assets/input/test-combined.fastq_block_44': {'mean_read_length': 457.876,
#   'min_read_length': 161,
#   'max_read_length': 3360,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 218.67500685720807,
#   'average_read_quality': 18.054062671989797},
#  'assets/input/test-combined.fastq_block_45': {'mean_read_length': 446.237,
#   'min_read_length': 161,
#   'max_read_length': 1355,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 195.6626148016018,
#   'average_read_quality': 17.824454269816265},
#  'assets/input/test-combined.fastq_block_46': {'mean_read_length': 451.727,
#   'min_read_length': 183,
#   'max_read_length': 1233,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 198.94231443059067,
#   'average_read_quality': 17.820610678573562},
#  'assets/input/test-combined.fastq_block_47': {'mean_read_length': 458.604,
#   'min_read_length': 146,
#   'max_read_length': 1152,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 199.39102583616946,
#   'average_read_quality': 17.799611429468563},
#  'assets/input/test-combined.fastq_block_48': {'mean_read_length': 453.098,
#   'min_read_length': 179,
#   'max_read_length': 4191,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 231.39871736031728,
#   'average_read_quality': 17.931387911665908},
#  'assets/input/test-combined.fastq_block_49': {'mean_read_length': 452.918,
#   'min_read_length': 159,
#   'max_read_length': 976,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 196.11409249719918,
#   'average_read_quality': 17.730386074300426},
#  'assets/input/test-combined.fastq_block_50': {'mean_read_length': 434.031,
#   'min_read_length': 149,
#   'max_read_length': 944,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 189.57036171036864,
#   'average_read_quality': 17.773000085247368},
#  'assets/input/test-combined.fastq_block_51': {'mean_read_length': 459.59,
#   'min_read_length': 179,
#   'max_read_length': 937,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 198.74006113514207,
#   'average_read_quality': 17.858623990948455},
#  'assets/input/test-combined.fastq_block_52': {'mean_read_length': 450.591,
#   'min_read_length': 176,
#   'max_read_length': 942,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 193.3138684083478,
#   'average_read_quality': 17.769305201391063},
#  'assets/input/test-combined.fastq_block_53': {'mean_read_length': 451.617,
#   'min_read_length': 171,
#   'max_read_length': 1070,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 194.77296606818925,
#   'average_read_quality': 17.873778002156694},
#  'assets/input/test-combined.fastq_block_54': {'mean_read_length': 452.876,
#   'min_read_length': 159,
#   'max_read_length': 1298,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 195.7986226304976,
#   'average_read_quality': 17.603381499571626},
#  'assets/input/test-combined.fastq_block_55': {'mean_read_length': 451.212,
#   'min_read_length': 143,
#   'max_read_length': 1110,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 199.67121238676344,
#   'average_read_quality': 17.77184117443685},
#  'assets/input/test-combined.fastq_block_56': {'mean_read_length': 454.876,
#   'min_read_length': 181,
#   'max_read_length': 941,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 196.43691258009528,
#   'average_read_quality': 17.81160580026205},
#  'assets/input/test-combined.fastq_block_57': {'mean_read_length': 462.732,
#   'min_read_length': 190,
#   'max_read_length': 1305,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 196.2359961271122,
#   'average_read_quality': 17.777960028699116},
#  'assets/input/test-combined.fastq_block_58': {'mean_read_length': 452.871,
#   'min_read_length': 151,
#   'max_read_length': 1173,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 197.80488456810158,
#   'average_read_quality': 17.773920167111605},
#  'assets/input/test-combined.fastq_block_59': {'mean_read_length': 453.032,
#   'min_read_length': 169,
#   'max_read_length': 1043,
#   'number_of_reads': 1000,
#   'std_dev_read_length': 198.1722457257827,
#   'average_read_quality': 17.739239170742906}}

# %%
import matplotlib.pyplot as plt

# Extract data for plotting
mean_lengths = [stats_map[key]['mean_read_length'] for key in stats_map]
min_lengths = [stats_map[key]['min_read_length'] for key in stats_map]
max_lengths = [stats_map[key]['max_read_length'] for key in stats_map]
std_devs = [stats_map[key]['std_dev_read_length'] for key in stats_map]
avg_qualities = [stats_map[key]['average_read_quality'] for key in stats_map]
num_reads = [stats_map[key]['number_of_reads'] for key in stats_map]
blocks = range(len(stats_map))

# Calculating overall averages
overall_avg_mean_length = sum(mean_lengths) / len(mean_lengths)
overall_avg_min_length = sum(min_lengths) / len(min_lengths)
overall_avg_max_length = sum(max_lengths) / len(max_lengths)
overall_avg_std_dev = sum(std_devs) / len(std_devs)
overall_avg_quality = sum(avg_qualities) / len(avg_qualities)
overall_avg_num_reads = sum(num_reads) / len(num_reads)

# Plotting with average lines
plt.figure(figsize=(18, 12))

# Mean Read Length
plt.subplot(2, 3, 1)
plt.plot(blocks, mean_lengths, marker='o')
plt.axhline(y=overall_avg_mean_length, color='r', linestyle='--')
plt.title('Mean Read Length per Block')
plt.xlabel('Block Number')
plt.ylabel('Mean Read Length')

# Min Read Length
plt.subplot(2, 3, 2)
plt.plot(blocks, min_lengths, marker='o')
plt.axhline(y=overall_avg_min_length, color='r', linestyle='--')
plt.title('Min Read Length per Block')
plt.xlabel('Block Number')
plt.ylabel('Min Read Length')

# Max Read Length
plt.subplot(2, 3, 3)
plt.plot(blocks, max_lengths, marker='o')
plt.axhline(y=overall_avg_max_length, color='r', linestyle='--')
plt.title('Max Read Length per Block')
plt.xlabel('Block Number')
plt.ylabel('Max Read Length')

# Standard Deviation of Read Length
plt.subplot(2, 3, 4)
plt.plot(blocks, std_devs, marker='o')
plt.axhline(y=overall_avg_std_dev, color='r', linestyle='--')
plt.title('Standard Deviation of Read Length per Block')
plt.xlabel('Block Number')
plt.ylabel('Standard Deviation')

# Average Quality
plt.subplot(2, 3, 5)
plt.plot(blocks, avg_qualities, marker='o')

plt.axhline(y=overall_avg_quality, color='r', linestyle='--')
plt.title('Average Read Quality per Block')
plt.xlabel('Block Number')
plt.ylabel('Average Quality')

# Number of Reads
plt.subplot(2, 3, 6)
plt.plot(blocks, num_reads, marker='o')
plt.axhline(y=overall_avg_num_reads, color='r', linestyle='--')
plt.title('Number of Reads per Block')
plt.xlabel('Block Number')
plt.ylabel('Number of Reads')

plt.tight_layout()
plt.show()
