# %%
from Bio import SeqIO
import matplotlib.pyplot as plt

# %%
fastq_path = '../assets/input/test-combined.fastq'  # Adjust the path if your file is in a different directory

read_lengths = []
read_qualities = []

for record in SeqIO.parse(fastq_path, 'fastq'):
    read_lengths.append(len(record.seq))
    read_qualities.append(record.letter_annotations["phred_quality"])

# %%
plt.figure(figsize=(10, 6))
plt.hist(read_lengths, bins=50, range=(0, 1000), color='blue', alpha=0.7)  # Adjusted bin size and range
plt.title('Distribution of Read Lengths (0 to 1000)')
plt.xlabel('Read Length')
plt.ylabel('Frequency')
plt.show()

# %%
average_qualities = [sum(quals)/len(quals) for quals in read_qualities if len(quals) > 0]

plt.figure(figsize=(10, 6))
plt.hist(average_qualities, bins=30, color='green', alpha=0.7)
plt.title('Distribution of Average Read Qualities')
plt.xlabel('Average Quality Score')
plt.ylabel('Frequency')
plt.show()

# %%
import numpy as np

# Assuming read_lengths and average_qualities are already defined as per previous steps

# Calculate the required statistics
mean_read_length = np.mean(read_lengths)
min_read_length = np.min(read_lengths)
max_read_length = np.max(read_lengths)
num_reads = len(read_lengths)
std_dev_read_length = np.std(read_lengths)
average_read_quality = np.mean(average_qualities)

# Store in a dictionary
filename = 'test.fastq'  # Replace with your actual filename
stats_map = {
    filename: {
        'mean_read_length': mean_read_length,
        'min_read_length': min_read_length,
        'max_read_length': max_read_length,
        'number_of_reads': num_reads,
        'std_dev_read_length': std_dev_read_length,
        'average_read_quality': average_read_quality
    }
}

# To access the stored information, use:
stats_map[filename]
# Out:
# {'mean_read_length': 453.38873333333333,
#  'min_read_length': 125,
#  'max_read_length': 5044,
#  'number_of_reads': 60000,
#  'std_dev_read_length': 199.88657346871057,
#  'average_read_quality': 17.70668201940736}

# %%
from Bio import SeqIO
import numpy as np

def process_fastq_in_blocks_and_store_stats(fastq_path, block_size=3000):
    block_number = 0
    stats_map = {}
    current_block_reads = []
    current_block_qualities = []

    with open(fastq_path, 'r') as fastq_file:
        for record in SeqIO.parse(fastq_file, 'fastq'):
            current_block_reads.append(len(record.seq))
            current_block_qualities.extend(record.letter_annotations["phred_quality"])

            if len(current_block_reads) == block_size:
                # Calculate statistics for the current block
                mean_read_length = np.mean(current_block_reads)
                min_read_length = np.min(current_block_reads)
                max_read_length = np.max(current_block_reads)
                std_dev_read_length = np.std(current_block_reads)
                average_read_quality = np.mean(current_block_qualities)

                # Store in the dictionary
                block_key = f"{fastq_path}_block_{block_number}"
                stats_map[block_key] = {
                    'mean_read_length': mean_read_length,
                    'min_read_length': min_read_length,
                    'max_read_length': max_read_length,
                    'number_of_reads': block_size,
                    'std_dev_read_length': std_dev_read_length,
                    'average_read_quality': average_read_quality
                }

                # Reset for the next block
                current_block_reads = []
                current_block_qualities = []
                block_number += 1

        # Handle the last block if it's not empty and less than block_size
        if current_block_reads:
            mean_read_length = np.mean(current_block_reads)
            min_read_length = np.min(current_block_reads)
            max_read_length = np.max(current_block_reads)
            std_dev_read_length = np.std(current_block_reads)
            average_read_quality = np.mean(current_block_qualities)

            block_key = f"{fastq_path}_block_{block_number}"
            stats_map[block_key] = {
                'mean_read_length': mean_read_length,
                'min_read_length': min_read_length,
                'max_read_length': max_read_length,
                'number_of_reads': len(current_block_reads),
                'std_dev_read_length': std_dev_read_length,
                'average_read_quality': average_read_quality
            }

    return stats_map

# Example usage
fastq_path = '../assets/input/test-combined.fastq'  # Adjust the path if your file is in a different directory
stats_map = process_fastq_in_blocks_and_store_stats(fastq_path)

# %%
stats_map
# Out:
# {'../assets/input/test-combined.fastq_block_0': {'mean_read_length': 453.749,
#   'min_read_length': 164,
#   'max_read_length': 1078,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 200.79453677577985,
#   'average_read_quality': 17.907124129566494},
#  '../assets/input/test-combined.fastq_block_1': {'mean_read_length': 456.993,
#   'min_read_length': 168,
#   'max_read_length': 1296,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 198.25865836746365,
#   'average_read_quality': 17.85772648596368},
#  '../assets/input/test-combined.fastq_block_2': {'mean_read_length': 447.27866666666665,
#   'min_read_length': 129,
#   'max_read_length': 1115,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 195.46253267115472,
#   'average_read_quality': 17.79488253408017},
#  '../assets/input/test-combined.fastq_block_3': {'mean_read_length': 459.3283333333333,
#   'min_read_length': 168,
#   'max_read_length': 1447,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 198.03440239149248,
#   'average_read_quality': 17.855970855996254},
#  '../assets/input/test-combined.fastq_block_4': {'mean_read_length': 453.123,
#   'min_read_length': 158,
#   'max_read_length': 998,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 198.82490086589593,
#   'average_read_quality': 17.821730523500243},
#  '../assets/input/test-combined.fastq_block_5': {'mean_read_length': 453.415,
#   'min_read_length': 125,
#   'max_read_length': 1182,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 198.45039037922467,
#   'average_read_quality': 17.879177648144267},
#  '../assets/input/test-combined.fastq_block_6': {'mean_read_length': 457.47833333333335,
#   'min_read_length': 152,
#   'max_read_length': 1362,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 202.20939360941887,
#   'average_read_quality': 17.824954915897656},
#  '../assets/input/test-combined.fastq_block_7': {'mean_read_length': 451.56466666666665,
#   'min_read_length': 147,
#   'max_read_length': 1227,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 195.85067224347796,
#   'average_read_quality': 17.797755803155546},
#  '../assets/input/test-combined.fastq_block_8': {'mean_read_length': 451.935,
#   'min_read_length': 153,
#   'max_read_length': 1027,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 199.18092807378255,
#   'average_read_quality': 17.785123229372957},
#  '../assets/input/test-combined.fastq_block_9': {'mean_read_length': 455.396,
#   'min_read_length': 154,
#   'max_read_length': 4170,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 209.27052153612078,
#   'average_read_quality': 17.962177972577713},
#  '../assets/input/test-combined.fastq_block_10': {'mean_read_length': 453.2613333333333,
#   'min_read_length': 129,
#   'max_read_length': 1064,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 196.06502927571987,
#   'average_read_quality': 17.87960440775888},
#  '../assets/input/test-combined.fastq_block_11': {'mean_read_length': 456.58366666666666,
#   'min_read_length': 148,
#   'max_read_length': 1102,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 197.94313240563704,
#   'average_read_quality': 17.872882005561596},
#  '../assets/input/test-combined.fastq_block_12': {'mean_read_length': 453.3093333333333,
#   'min_read_length': 158,
#   'max_read_length': 5044,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 212.23613966418523,
#   'average_read_quality': 17.949503208993416},
#  '../assets/input/test-combined.fastq_block_13': {'mean_read_length': 450.34066666666666,
#   'min_read_length': 159,
#   'max_read_length': 942,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 194.53112333563035,
#   'average_read_quality': 17.91203992236988},
#  '../assets/input/test-combined.fastq_block_14': {'mean_read_length': 452.01466666666664,
#   'min_read_length': 129,
#   'max_read_length': 3360,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 203.84335109315901,
#   'average_read_quality': 17.857385158593672},
#  '../assets/input/test-combined.fastq_block_15': {'mean_read_length': 452.1893333333333,
#   'min_read_length': 146,
#   'max_read_length': 1355,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 198.0702539156807,
#   'average_read_quality': 17.814775964050458},
#  '../assets/input/test-combined.fastq_block_16': {'mean_read_length': 446.68233333333336,
#   'min_read_length': 149,
#   'max_read_length': 4191,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 206.70681835526267,
#   'average_read_quality': 17.81215136484019},
#  '../assets/input/test-combined.fastq_block_17': {'mean_read_length': 453.93266666666665,
#   'min_read_length': 171,
#   'max_read_length': 1070,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 195.66374762047488,
#   'average_read_quality': 17.83409580569218},
#  '../assets/input/test-combined.fastq_block_18': {'mean_read_length': 452.988,
#   'min_read_length': 143,
#   'max_read_length': 1298,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 197.3152178351516,
#   'average_read_quality': 17.72901195322319},
#  '../assets/input/test-combined.fastq_block_19': {'mean_read_length': 456.21166666666664,
#   'min_read_length': 151,
#   'max_read_length': 1305,
#   'number_of_reads': 3000,
#   'std_dev_read_length': 197.460006576578,
#   'average_read_quality': 17.76380627413445}}

# %%
import matplotlib.pyplot as plt

# Extract data for plotting
mean_lengths = [stats_map[key]['mean_read_length'] for key in stats_map]
min_lengths = [stats_map[key]['min_read_length'] for key in stats_map]
max_lengths = [stats_map[key]['max_read_length'] for key in stats_map]
std_devs = [stats_map[key]['std_dev_read_length'] for key in stats_map]
avg_qualities = [stats_map[key]['average_read_quality'] for key in stats_map]
num_reads = [stats_map[key]['number_of_reads'] for key in stats_map]
blocks = range(len(stats_map))

# Calculating overall averages
overall_avg_mean_length = sum(mean_lengths) / len(mean_lengths)
overall_avg_min_length = sum(min_lengths) / len(min_lengths)
overall_avg_max_length = sum(max_lengths) / len(max_lengths)
overall_avg_std_dev = sum(std_devs) / len(std_devs)
overall_avg_quality = sum(avg_qualities) / len(avg_qualities)
overall_avg_num_reads = sum(num_reads) / len(num_reads)

# Plotting with average lines
plt.figure(figsize=(18, 12))

# Mean Read Length
plt.subplot(2, 3, 1)
plt.plot(blocks, mean_lengths, marker='o')
plt.axhline(y=overall_avg_mean_length, color='r', linestyle='--')
plt.title('Mean Read Length per Block')
plt.xlabel('Block Number')
plt.ylabel('Mean Read Length')

# Min Read Length
plt.subplot(2, 3, 2)
plt.plot(blocks, min_lengths, marker='o')
plt.axhline(y=overall_avg_min_length, color='r', linestyle='--')
plt.title('Min Read Length per Block')
plt.xlabel('Block Number')
plt.ylabel('Min Read Length')

# Max Read Length
plt.subplot(2, 3, 3)
plt.plot(blocks, max_lengths, marker='o')
plt.axhline(y=overall_avg_max_length, color='r', linestyle='--')
plt.title('Max Read Length per Block')
plt.xlabel('Block Number')
plt.ylabel('Max Read Length')

# Standard Deviation of Read Length
plt.subplot(2, 3, 4)
plt.plot(blocks, std_devs, marker='o')
plt.axhline(y=overall_avg_std_dev, color='r', linestyle='--')
plt.title('Standard Deviation of Read Length per Block')
plt.xlabel('Block Number')
plt.ylabel('Standard Deviation')

# Average Quality
plt.subplot(2, 3, 5)
plt.plot(blocks, avg_qualities, marker='o')

plt.axhline(y=overall_avg_quality, color='r', linestyle='--')
plt.title('Average Read Quality per Block')
plt.xlabel('Block Number')
plt.ylabel('Average Quality')

# Number of Reads
plt.subplot(2, 3, 6)
plt.plot(blocks, num_reads, marker='o')
plt.axhline(y=overall_avg_num_reads, color='r', linestyle='--')
plt.title('Number of Reads per Block')
plt.xlabel('Block Number')
plt.ylabel('Number of Reads')

plt.tight_layout()
plt.show()

# %%
# print the number of blocks
print(f"Number of blocks: {len(stats_map)}")
# Out:
# Number of blocks: 20

# %%
from Bio import SeqIO
import numpy as np



# Example usage
fastq_path = 'assets/input/test-combined.fastq'  # Adjust the path if your file is in a different directory
stats_map = process_fastq_in_blocks_and_store_stats(fastq_path)
