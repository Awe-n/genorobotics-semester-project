# %%
from Bio import SeqIO

def process_fastq_in_blocks(fastq_path, block_size=200):
    block_number = 0
    read_count = 0

    with open(fastq_path, 'r') as fastq_file:
        for record in SeqIO.parse(fastq_file, 'fastq'):
            if read_count % block_size == 0 and read_count > 0:
                print(f"Processed block number: {block_number}")
                block_number += 1
            read_count += 1

        # Handle the last block
        if read_count % block_size != 0:
            print(f"Processed block number: {block_number}")

# Example usage
fastq_path = '../assets/input/test-combined.fastq'  # Adjust the path if your file is in a different directory
process_fastq_in_blocks(fastq_path)
# Out:
# Processed block number: 0
# Processed block number: 1
# Processed block number: 2
# Processed block number: 3
# Processed block number: 4
# Processed block number: 5
# Processed block number: 6
# Processed block number: 7
# Processed block number: 8
# Processed block number: 9
# Processed block number: 10
# Processed block number: 11
# Processed block number: 12
# Processed block number: 13
# Processed block number: 14
# Processed block number: 15
# Processed block number: 16
# Processed block number: 17
# Processed block number: 18
# Processed block number: 19
# Processed block number: 20
# Processed block number: 21
# Processed block number: 22
# Processed block number: 23
# Processed block number: 24
# Processed block number: 25
# Processed block number: 26
# Processed block number: 27
# Processed block number: 28
# Processed block number: 29
# Processed block number: 30
# Processed block number: 31
# Processed block number: 32
# Processed block number: 33
# Processed block number: 34
# Processed block number: 35
# Processed block number: 36
# Processed block number: 37
# Processed block number: 38
# Processed block number: 39
# Processed block number: 40
# Processed block number: 41
# Processed block number: 42
# Processed block number: 43
# Processed block number: 44
# Processed block number: 45
# Processed block number: 46
# Processed block number: 47
# Processed block number: 48
# Processed block number: 49
# Processed block number: 50
# Processed block number: 51
# Processed block number: 52
# Processed block number: 53
# Processed block number: 54
# Processed block number: 55
# Processed block number: 56
# Processed block number: 57
# Processed block number: 58
# Processed block number: 59
# Processed block number: 60
# Processed block number: 61
# Processed block number: 62
# Processed block number: 63
# Processed block number: 64
# Processed block number: 65
# Processed block number: 66
# Processed block number: 67
# Processed block number: 68
# Processed block number: 69
# Processed block number: 70
# Processed block number: 71
# Processed block number: 72
# Processed block number: 73
# Processed block number: 74
# Processed block number: 75
# Processed block number: 76
# Processed block number: 77
# Processed block number: 78
# Processed block number: 79
# Processed block number: 80
# Processed block number: 81
# Processed block number: 82
# Processed block number: 83
# Processed block number: 84
# Processed block number: 85
# Processed block number: 86
# Processed block number: 87
# Processed block number: 88
# Processed block number: 89
# Processed block number: 90
# Processed block number: 91
# Processed block number: 92
# Processed block number: 93
# Processed block number: 94
# Processed block number: 95
# Processed block number: 96
# Processed block number: 97
# Processed block number: 98
# Processed block number: 99
# Processed block number: 100
# Processed block number: 101
# Processed block number: 102
# Processed block number: 103
# Processed block number: 104
# Processed block number: 105
# Processed block number: 106
# Processed block number: 107
# Processed block number: 108
# Processed block number: 109
# Processed block number: 110
# Processed block number: 111
# Processed block number: 112
# Processed block number: 113
# Processed block number: 114
# Processed block number: 115
# Processed block number: 116
# Processed block number: 117
# Processed block number: 118
# Processed block number: 119
# Processed block number: 120
# Processed block number: 121
# Processed block number: 122
# Processed block number: 123
# Processed block number: 124
# Processed block number: 125
# Processed block number: 126
# Processed block number: 127
# Processed block number: 128
# Processed block number: 129
# Processed block number: 130
# Processed block number: 131
# Processed block number: 132
# Processed block number: 133
# Processed block number: 134
# Processed block number: 135
# Processed block number: 136
# Processed block number: 137
# Processed block number: 138
# Processed block number: 139
# Processed block number: 140
# Processed block number: 141
# Processed block number: 142
# Processed block number: 143
# Processed block number: 144
# Processed block number: 145
# Processed block number: 146
# Processed block number: 147
# Processed block number: 148
# Processed block number: 149
# Processed block number: 150
# Processed block number: 151
# Processed block number: 152
# Processed block number: 153
# Processed block number: 154
# Processed block number: 155
# Processed block number: 156
# Processed block number: 157
# Processed block number: 158
# Processed block number: 159
# Processed block number: 160
# Processed block number: 161
# Processed block number: 162
# Processed block number: 163
# Processed block number: 164
# Processed block number: 165
# Processed block number: 166
# Processed block number: 167
# Processed block number: 168
# Processed block number: 169
# Processed block number: 170
# Processed block number: 171
# Processed block number: 172
# Processed block number: 173
# Processed block number: 174
# Processed block number: 175
# Processed block number: 176
# Processed block number: 177
# Processed block number: 178
# Processed block number: 179
# Processed block number: 180
# Processed block number: 181
# Processed block number: 182
# Processed block number: 183
# Processed block number: 184
# Processed block number: 185
# Processed block number: 186
# Processed block number: 187
# Processed block number: 188
# Processed block number: 189
# Processed block number: 190
# Processed block number: 191
# Processed block number: 192
# Processed block number: 193
# Processed block number: 194
# Processed block number: 195
# Processed block number: 196
# Processed block number: 197
# Processed block number: 198
# Processed block number: 199
# Processed block number: 200
# Processed block number: 201
# Processed block number: 202
# Processed block number: 203
# Processed block number: 204
# Processed block number: 205
# Processed block number: 206
# Processed block number: 207
# Processed block number: 208
# Processed block number: 209
# Processed block number: 210
# Processed block number: 211
# Processed block number: 212
# Processed block number: 213
# Processed block number: 214
# Processed block number: 215
# Processed block number: 216
# Processed block number: 217
# Processed block number: 218
# Processed block number: 219
# Processed block number: 220
# Processed block number: 221
# Processed block number: 222
# Processed block number: 223
# Processed block number: 224
# Processed block number: 225
# Processed block number: 226
# Processed block number: 227
# Processed block number: 228
# Processed block number: 229
# Processed block number: 230
# Processed block number: 231
# Processed block number: 232
# Processed block number: 233
# Processed block number: 234
# Processed block number: 235
# Processed block number: 236
# Processed block number: 237
# Processed block number: 238
# Processed block number: 239
# Processed block number: 240
# Processed block number: 241
# Processed block number: 242
# Processed block number: 243
# Processed block number: 244
# Processed block number: 245
# Processed block number: 246
# Processed block number: 247
# Processed block number: 248
# Processed block number: 249
# Processed block number: 250
# Processed block number: 251
# Processed block number: 252
# Processed block number: 253
# Processed block number: 254
# Processed block number: 255
# Processed block number: 256
# Processed block number: 257
# Processed block number: 258
# Processed block number: 259
# Processed block number: 260
# Processed block number: 261
# Processed block number: 262
# Processed block number: 263
# Processed block number: 264
# Processed block number: 265
# Processed block number: 266
# Processed block number: 267
# Processed block number: 268
# Processed block number: 269
# Processed block number: 270
# Processed block number: 271
# Processed block number: 272
# Processed block number: 273
# Processed block number: 274
# Processed block number: 275
# Processed block number: 276
# Processed block number: 277
# Processed block number: 278
# Processed block number: 279
# Processed block number: 280
# Processed block number: 281
# Processed block number: 282
# Processed block number: 283
# Processed block number: 284
# Processed block number: 285
# Processed block number: 286
# Processed block number: 287
# Processed block number: 288
# Processed block number: 289
# Processed block number: 290
# Processed block number: 291
# Processed block number: 292
# Processed block number: 293
# Processed block number: 294
# Processed block number: 295
# Processed block number: 296
# Processed block number: 297
# Processed block number: 298

# %%
from Bio import SeqIO
import numpy as np
import matplotlib.pyplot as plt

fastq_path = '../assets/input/test-combined.fastq'  # Adjust the path if your file is in a different directory
# Initialize a list to store quality scores for each base position
quality_per_base = []

# Read the FASTQ file and accumulate quality scores
with open(fastq_path, 'r') as fastq_file:
    for record in SeqIO.parse(fastq_file, 'fastq'):
        while len(quality_per_base) < len(record.seq):
            quality_per_base.append([])

        for i, quality in enumerate(record.letter_annotations["phred_quality"]):
            quality_per_base[i].append(quality)

# Calculate the average quality score per base
average_quality_per_base = [np.mean(quals) for quals in quality_per_base]

# Plotting the average quality score per base
plt.figure(figsize=(10, 6))
plt.plot(average_quality_per_base, color='blue')
plt.title('Average Quality Score Per Base Position')
plt.xlabel('Base Position')
plt.ylabel('Average Quality Score')
plt.show()

# %%
from Bio import SeqIO
import matplotlib.pyplot as plt

fastq_path = '../assets/input/test-combined.fastq'  # Adjust the path to your FASTQ file

# Read the FASTQ file and process only the first read
with open(fastq_path, 'r') as fastq_file:
    first_record = next(SeqIO.parse(fastq_file, 'fastq'))
    quality_scores = first_record.letter_annotations["phred_quality"]

# Plotting the quality scores for the first read
plt.figure(figsize=(10, 6))
plt.plot(quality_scores, color='blue')
plt.title('Quality Scores for the First Read')
plt.xlabel('Base Position')
plt.ylabel('Quality Score')
plt.show()
